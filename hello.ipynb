# %% [markdown]
# # Introduction to Jupyter Notebook
#
# ```bash
# import leafmap
# ```

# %%
print ("Hello, World!")

# %%
import os

# %%
os.getcwd()

# %%
import leafmap

# %%
m = leafmap.Map()
m.add_basemap("HYBRID")
m
